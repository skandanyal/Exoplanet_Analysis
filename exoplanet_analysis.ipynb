# %%
import pandas as pd

# %%
df = pd.read_csv("Nasa_exoplanet_archive.csv")
df
# Out:
#        loc_rowid    pl_name hostname  default_flag  sy_snum  sy_pnum  sy_mnum  \
# 0              1   11 Com b   11 Com             0        2        1        0
# 1              2   11 Com b   11 Com             0        2        1        0
# 2              3   11 Com b   11 Com             1        2        1        0
# 3              4   11 UMi b   11 UMi             1        1        1        0
# 4              5   11 UMi b   11 UMi             0        1        1        0
# ...          ...        ...      ...           ...      ...      ...      ...
# 38152      38153  ups And d  ups And             0        2        3        0
# 38153      38154  ups Leo b  ups Leo             1        1        1        0
# 38154      38155   xi Aql b   xi Aql             0        1        1        0
# 38155      38156   xi Aql b   xi Aql             0        1        1        0
# 38156      38157   xi Aql b   xi Aql             1        1        1        0
#
# ...

# %%
import
# Out:
# 1

# %%
from column_desc import column_description

print(column_description)
# Out:
# # This file was produced by the NASA Exoplanet Archive  http://exoplanetarchive.ipac.caltech.edu
# # Mon Mar 17 10:14:26 2025
# #
# # User preference: *
# #
# # COLUMN pl_name:        Planet Name
# # COLUMN hostname:       Host Name
# # COLUMN default_flag:   Default Parameter Set
# # COLUMN sy_snum:        Number of Stars
# # COLUMN sy_pnum:        Number of Planets
# # COLUMN sy_mnum:        Number of Moons
# # COLUMN discoverymethod: Discovery Method
# # COLUMN disc_year:      Discovery Year
# # COLUMN disc_locale:    Discovery Locale
# # COLUMN disc_facility:  Discovery Facility
# # COLUMN disc_telescope: Discovery Telescope
# # COLUMN disc_instrument: Discovery Instrument
# # COLUMN rv_flag:        Detected by Radial Velocity Variations
# # COLUMN pl_controv_flag: Controversial Flag
# # COLUMN pl_refname:     Planetary Parameter Reference
# # COLUMN pl_orbper:      Orbital Period [days]
# # COLUMN pl_orbsmax:     Orbit Semi-Major Axis [au]
# ...

# %%
rows_to_delete = '''
# COLUMN rastr:          RA [sexagesimal]
# COLUMN ra:             RA [deg]
# COLUMN decstr:         Dec [sexagesimal]
# COLUMN dec:            Dec [deg]
# COLUMN sy_dist:        Distance [pc]
# COLUMN sy_vmag:        V (Johnson) Magnitude
# COLUMN sy_gaiamag:     Gaia Magnitude
# COLUMN disc_telescope: Discovery Telescope
# COLUMN disc_instrument: Discovery Instrument
# COLUMN rv_flag:        Detected by Radial Velocity Variations
# COLUMN pl_controv_flag: Controversial Flag
'''

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38157 entries, 0 to 38156
# Data columns (total 50 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   loc_rowid        38157 non-null  int64
#  1   pl_name          38157 non-null  object
#  2   hostname         38157 non-null  object
#  3   default_flag     38157 non-null  int64
#  4   sy_snum          38157 non-null  int64
#  5   sy_pnum          38157 non-null  int64
#  6   sy_mnum          38157 non-null  int64
#  7   discoverymethod  38157 non-null  object
#  8   disc_year        38157 non-null  int64
#  9   disc_locale      38157 non-null  object
#  10  disc_facility    38157 non-null  object
#  11  disc_telescope   38157 non-null  object
#  12  disc_instrument  38157 non-null  object
#  13  rv_flag          38157 non-null  int64
#  14  pl_controv_flag  38157 non-null  int64
#  15  pl_refname       38157 non-null  object
#  16  pl_orbper        34971 non-null  float64
# ...

# %%
df.describe()
# Out:
#           loc_rowid  default_flag       sy_snum       sy_pnum  sy_mnum  \
# count  38157.000000  38157.000000  38157.000000  38157.000000  38157.0
# mean   19079.000000      0.153471      1.084991      1.900857      0.0
# std    11015.121447      0.360446      0.309093      1.212442      0.0
# min        1.000000      0.000000      1.000000      1.000000      0.0
# 25%     9540.000000      0.000000      1.000000      1.000000      0.0
# 50%    19079.000000      0.000000      1.000000      1.000000      0.0
# 75%    28618.000000      0.000000      1.000000      2.000000      0.0
# max    38157.000000      1.000000      4.000000      8.000000      0.0
#
#           disc_year       rv_flag  pl_controv_flag     pl_orbper  \
# count  38157.000000  38157.000000     38157.000000  3.497100e+04
# mean    2015.454202      0.239196         0.002149  1.248799e+04
# std        3.902064      0.426598         0.046308  2.150920e+06
# min     1992.000000      0.000000         0.000000  9.070629e-02
# ...

# %%
df.head()
# Out:
#    loc_rowid   pl_name hostname  default_flag  sy_snum  sy_pnum  sy_mnum  \
# 0          1  11 Com b   11 Com             0        2        1        0
# 1          2  11 Com b   11 Com             0        2        1        0
# 2          3  11 Com b   11 Com             1        2        1        0
# 3          4  11 UMi b   11 UMi             1        1        1        0
# 4          5  11 UMi b   11 UMi             0        1        1        0
#
#    discoverymethod  disc_year disc_locale  ...         rastr          ra  \
# 0  Radial Velocity       2007      Ground  ...  12h20m42.91s  185.178779
# 1  Radial Velocity       2007      Ground  ...  12h20m42.91s  185.178779
# 2  Radial Velocity       2007      Ground  ...  12h20m42.91s  185.178779
# 3  Radial Velocity       2009      Ground  ...  15h17m05.90s  229.274595
# 4  Radial Velocity       2009      Ground  ...  15h17m05.90s  229.274595
#
#           decstr        dec   sy_dist  sy_vmag  sy_gaiamag   rowupdate  \
# ...

# %% [markdown]
# Exoplanet Discovery Trends Over Time
# Question: How has exoplanet discovery evolved over the years?
# Visualization:
#
# Bar chart: Number of exoplanets discovered per year.
# Line graph: Cumulative discoveries over time.
# Color-code by detection method (Transit, Radial Velocity, etc.).
# Extra: Compare discovery rates for different methods!

# %% [markdown]
# Mass vs. Radius – Exoplanet Types
# Question: How do exoplanets compare to Earth, Jupiter, and Neptune?
# Visualization:
#
# Scatter plot (Mass vs. Radius) → Differentiate Earth-like, Super-Earths, Neptune-like, and Gas Giants.
# Add reference lines for Earth, Neptune, and Jupiter.
# Color-code by planet type.
# Extra: Fit a trend line and check if mass-radius relationships match theoretical models!

# %% [markdown]
# Orbital Period vs. Distance from Star (Kepler’s Laws Check)
# Question: Do exoplanets follow predictable orbital patterns?
# Visualization:
#
# Log-log scatter plot (Orbital Period vs. Semi-Major Axis).
# Overlay Kepler’s Third Law curve for reference.
# Highlight planets with extreme orbits.
# Extra: Check if larger planets have longer orbital periods!

# %% [markdown]
# Exoplanet Temperature Distribution
# Question: What’s the temperature range of discovered exoplanets?
# Visualization:
#
# Histogram of exoplanet temperatures.
# Highlight the habitable zone temperature range (~ -50°C to 100°C).
# Color-code planets based on their size/type.
# Extra: Compare the distribution for different detection methods!

# %% [markdown]
# Exoplanet Density Analysis – Rocky vs. Gas Giants
# Question: Are discovered exoplanets mostly rocky or gaseous?
# Visualization:
#
# Scatter plot (Density vs. Radius).
# Categorize planets into Rocky (High Density) vs. Gaseous (Low Density).
# Highlight Earth-like density range.
# Extra: Find outliers—are there super-dense gas giants or low-density rocky planets?

# %% [markdown]
# Number of Exoplanets Per Star System
# Question: How many exoplanets do stars typically have?
# Visualization:
#
# Bar chart showing how many stars have 1, 2, 3, or more exoplanets.
# Pie chart comparing single-planet vs. multi-planet systems.
# Extra: Check if multi-planet systems tend to have similar types of planets!
